# %% [markdown]
# # Analysis on Function Filtering Algorithm
# ## for [FEAT] Frequent Event Groups Relation

# %% [markdown]
# ### Traces used in experiment
# trace_API_image_classification.log: size 239 MB, lines 756312
# trace_API_text_classification.log:  size 470 MB, lines 528616
#
# These traces contains records of API calls on ```torch``` related functions excluding ```torch._C, torch._jit, torch.jit ```

# %% [markdown]
# ### Relation used in experiment
# ```
# relation_pool: list[Type] = [
#     FunctionLeadRelation
# ]
# ```

# %% [markdown]
# ### Invariant inference with no filtering function

# %% [markdown]
# No filtering function means that all traces will be taken into consider:
# ```
# events = trace.events
# function_pool_df = events
# function_pool = set(function_pool_df["function"].unique().to_list())
# ```

# %%
# Infer on trace_API_image_classification.log
# !time python -m mldaikon.infer_engine -t 'mldaikon/invariant/trace_API_image_classification.log' -d

# %% [markdown]
# ##### All functions
# ```text
# torch._VariableFunctionsClass.asarray
# torch._ops.OperatorBase.py_functionalize_impl
# torch._utils._get_devices_properties
# torch.utils._foreach_utils._get_fused_kernels_supported_devices
# torch.library.impl_abstract
# torch._check_not_implemented
# torch._utils._get_device_attr
# torch.is_autocast_cache_enabled
# torch.nn.modules.utils._reverse_repeat_tuple
# torch.nn.modules.container.ModuleList.extend
# torch._ops.HigherOrderOperator.__init__
# torch.cuda.is_initialized
# torch.cuda._is_compiled
# torch.utils.weak.WeakIdKeyDictionary.__init__
# torch.cuda.set_device
# torch.nn.parallel.data_parallel.DataParallel.forward
# torch.nn.functional.layer_norm
# torch._decomp._add_op_to_registry
# torch.utils.data.dataloader._BaseDataLoaderIter.__init__
# torch.cuda.random.manual_seed_all
# torch.optim.adamw.adamw
# torch._VariableFunctionsClass.zeros_like
# torch._library.simple_registry.SimpleOperatorEntry.__init__
# torch._utils._get_all_device_indices
# torch.serialization._save
# torch._VariableFunctionsClass._foreach_lerp_
# torch.storage.TypedStorage._element_size
# torch.autograd.grad_mode.set_grad_enabled.__init__
# torch._utils._take_tensors
# torch._VariableFunctionsClass._has_compatible_shallow_copy_type
# torch.optim.lr_scheduler.LRScheduler.get_last_lr
# torch.serialization._is_path
# torch._VariableFunctionsClass.is_complex
# torch._utils._reorder_tensors_as
# torch.nn.modules.dropout.Dropout.forward
# torch.utils.weak.WeakIdRef.__init__
# torch.optim.lr_scheduler._enable_get_lr_call.__init__
# torch._logging._internal.LogState.is_artifact_enabled
# torch._logging._internal.configure_artifact_log
# torch.nn.parallel.data_parallel._check_balance
# torch.utils._pytree._get_node_type
# torch.nn.parallel.replicate._replicatable_module
# torch._library.abstract_impl.construct_meta_kernel
# torch.backends.cuda.is_built
# torch._ops.OperatorBase.__init__
# torch._VariableFunctionsClass.isnan
# torch.nn.modules.module.Module.register_parameter
# torch.cuda.memory.empty_cache
# torch._utils._get_device_index
# torch._VariableFunctionsClass.layer_norm
# torch.utils._foreach_utils._group_tensors_by_device_and_dtype
# torch._ops.OpOverload.__call__
# torch.utils.data.dataloader._SingleProcessDataLoaderIter.__init__
# torch.cuda.set_stream
# torch.nn.modules.module.Module.register_buffer
# torch.utils.hooks.warn_if_has_hooks
# torch.distributed.rpc.is_available
# torch.library._scoped_library
# torch._ops.OpOverload.__init__
# torch.utils._pytree.register_pytree_node
# torch.autograd.graph._engine_run_backward
# torch.nn.parallel.comm.reduce_add_coalesced
# torch._ops.dl_open_guard
# torch._VariableFunctionsClass.from_numpy
# torch.optim.optimizer._get_value
# torch._decomp.register_decomposition
# torch.nn.modules.linear.Linear.__init__
# torch.overrides.is_tensor_like
# torch.nn.modules.conv._ConvNd.__init__
# torch._library.abstract_impl.AbstractImplHolder.__init__
# torch._higher_order_ops.utils.autograd_not_implemented
# torch._VariableFunctionsClass.clamp
# torch.xpu.is_initialized
# torch.cuda._utils._get_device_index
# torch._utils._handle_complex
# torch._logging._internal.LogRegistry.register_artifact_log
# torch._VariableFunctionsClass._foreach_add_
# torch._running_with_deploy
# torch.nn.parallel.data_parallel.DataParallel.parallel_apply
# torch.optim.optimizer.Optimizer._patch_step_function
# torch.optim.adamw.AdamW.step
# torch.nn.parallel.replicate._is_script_module
# torch.nn.modules.module.Module.state_dict
# torch._ops.HigherOrderOperator.py_impl
# torch.random.get_rng_state
# torch.nn.modules.module.Module._call_impl
# torch.utils._foreach_utils._get_foreach_kernels_supported_devices
# torch._prims_common.extract_shape_from_varargs
# torch._VariableFunctionsClass.ones_like
# torch.autograd.function.FunctionMeta.__init__
# torch.optim.optimizer.Optimizer.add_param_group
# torch.autograd.grad_mode.no_grad.__init__
# torch.cuda.nccl.is_available
# torch._check_is_size
# torch.cuda.current_stream
# torch.nn.parallel.data_parallel.DataParallel.scatter
# torch.nn.modules.module.Module._save_to_state_dict
# torch.cuda.PyCapsule._get_device_properties
# torch.utils._foreach_utils._has_foreach_support
# torch.nn.parallel.comm.broadcast_coalesced
# torch.utils._pytree._tree_flatten_helper
# torch.nn.modules.module.Module._wrapped_call_impl
# torch._VariableFunctionsClass.randint
# torch._compile._disable_dynamo
# torch.get_default_dtype
# torch.optim.lr_scheduler.LambdaLR.__init__
# torch.utils.data.dataloader._BaseDataLoaderIter._next_index
# torch.nn.modules.normalization.LayerNorm.__init__
# torch.optim.adamw.AdamW.__init__
# torch.nn.modules.module.Module.add_module
# torch.nn.modules.module.Module.parameters
# torch.utils.data.sampler.BatchSampler.__init__
# torch._VariableFunctionsClass._foreach_div_
# torch._VariableFunctionsClass.empty_like
# torch._ops._OpNamespace.__init__
# torch.utils.data.dataloader._SingleProcessDataLoaderIter._next_data
# torch.nn.init.trunc_normal_
# torch._library.utils.Kernel.__init__
# torch.nn.modules.module.Module.eval
# torch.is_autocast_enabled
# torch.nn.modules.normalization.LayerNorm.forward
# torch.utils.data._utils.fetch._BaseDatasetFetcher.__init__
# torch.random.initial_seed
# torch.autograd._tensor_or_tensors_to_tuple
# torch._VariableFunctionsClass.cat
# torch.mps.manual_seed
# torch.nn.modules.conv.Conv2d.forward
# torch.nn.modules.module.Module._named_members
# torch._ops.OpOverloadPacket.__call__
# torch.storage.TypedStorage._size
# torch.SymInt.__init__
# torch.nn.init._no_grad_fill_
# torch.cuda.StreamContext.__init__
# torch._utils._get_available_device_type
# torch._library.utils.RegistrationHandle.__init__
# torch.set_autocast_cache_enabled
# torch._classes._ClassNamespace.__init__
# torch._ops.HigherOrderOperator.fallthrough
# torch.autograd._make_grads
# torch._VariableFunctionsClass.log
# torch.utils.data.dataloader.DataLoader._get_iterator
# torch.distributed.distributed_c10d.is_initialized
# torch.library.Library.__init__
# torch.nn.modules.loss._WeightedLoss.__init__
# torch._VariableFunctionsClass._foreach_mul_
# torch.nn.modules.conv.Conv2d._conv_forward
# torch.nn.parallel.replicate.replicate
# torch._library.simple_registry.SimpleLibraryRegistry.find
# torch._prims_common.dtype_or_default
# torch.nn.modules.loss._Loss.__init__
# torch._utils._flatten_dense_tensors
# torch.cuda._set_stream_by_id
# torch._prims_common.is_float_dtype
# torch.library._check_pystubs_once
# torch._ops._Ops.load_library
# torch.library.Library.define
# torch.xpu.is_available
# torch.serialization._opener.__init__
# torch.nn.modules.module.Module.zero_grad
# torch._utils._LazySeedTracker.queue_seed_all
# torch._utils._unflatten_dense_tensors
# torch._VariableFunctionsClass.empty
# torch.nn.parallel.data_parallel.DataParallel.gather
# torch.nn.modules.module.Module._load_from_state_dict
# torch.optim.lr_scheduler._check_verbose_deprecated_warning
# torch.xpu._lazy_call
# torch.utils._contextlib._DecoratorContextManager.__call__
# torch._ops.OpOverloadPacket.overloads
# torch.serialization._check_dill_version
# torch.serialization.save
# torch.nn.parallel.parallel_apply.parallel_apply
# torch._utils._get_obj_state
# torch._VariableFunctionsClass.as_tensor
# torch.library.Library._destroy
# torch.storage._StorageBase.size
# torch._VariableFunctionsClass.isinf
# torch.get_autocast_gpu_dtype
# torch.serialization._open_zipfile_writer_file.__init__
# torch.xpu.<lambda>
# torch._guards.Guard.__init__
# torch.nn.modules.module.Module.named_parameters
# torch.nn.modules.activation.SiLU.__init__
# torch.utils._foreach_utils._device_has_foreach_support
# torch._VariableFunctionsClass.tensor
# torch.xpu._is_compiled
# torch._utils.get_tensor_metadata
# torch.nn.parallel.replicate._is_jit_enabled
# torch.nn.modules.module.Module.buffers
# torch.cuda._nvml_based_avail
# torch.package._mangling.is_mangled
# torch._prims_common.validate_dim_length
# torch.random.manual_seed
# torch.hub._get_torch_home
# torch.optim.lr_scheduler.LambdaLR.state_dict
# torch.functional.atleast_1d
# torch._library.utils.get_source
# torch.optim.adamw.AdamW._init_group
# torch.set_autocast_gpu_dtype
# torch.serialization.location_tag
# torch.utils.data.sampler.SequentialSampler.__init__
# torch._VariableFunctionsClass._foreach_addcdiv_
# torch.utils._python_dispatch.is_traceable_wrapper_subclass
# torch.library.Library.impl
# torch.cuda.nccl._check_sequence_type
# torch._functorch.utils.unwrap_dead_wrappers
# torch.nn.modules.linear.Linear.reset_parameters
# torch.nn._reduction.get_enum
# torch.backends.cuda.cuFFTPlanCache.__init__
# torch._utils._get_current_device_index
# torch.nn.init._no_grad_zero_
# torch._VariableFunctionsClass.stack
# torch.nn.modules.module.Module.to
# torch._VariableFunctionsClass.empty_strided
# torch.sym_max
# torch._utils_internal.resolve_library_path
# torch.nn.parallel.comm.scatter
# torch.utils.data.sampler.RandomSampler.__init__
# torch._logging._internal.LogRegistry.is_off_by_default
# torch.nn.parameter.is_lazy
# torch.utils._pytree.tree_map_
# torch.optim.lr_scheduler.LRScheduler._initial_step
# torch._prims_common.check_pin_memory
# torch.optim.optimizer._default_to_fused_or_foreach
# torch.autograd.profiler.record_function.__init__
# torch._tensor.Tensor._reduce_ex_internal
# torch.nn.modules.linear.Linear.forward
# torch.utils._pytree._is_leaf
# torch.nn.utils.clip_grad.clip_grad_norm_
# torch.optim.optimizer._get_scalar_dtype
# torch.nn.modules.module.Module._apply
# torch.storage._StorageBase.cpu
# torch.cuda.current_device
# torch._prims_common.validate_shape
# torch.utils._pytree._private_register_pytree_node
# torch._prims.TensorMeta
# torch.nn.parallel.scatter_gather.gather
# torch.cuda.nccl.reduce
# torch.utils._contextlib.context_decorator
# torch.optim.lr_scheduler.LRScheduler.step
# torch._tensor.Tensor.backward
# torch.nn.modules.utils._ntuple.<locals>.parse
# torch.optim.optimizer._dispatch_sqrt
# torch.nn.modules.module.Module.children
# torch.compiler.is_compiling
# torch.utils.data.dataloader.DataLoader.__init__
# torch.cuda.stream
# torch.clear_autocast_cache
# torch._VariableFunctionsClass.conv2d
# torch.nn.init.ones_
# torch._ops.OpOverloadPacket.__init__
# torch._namedtensor_internals.check_serializing_named_tensor
# torch.optim.lr_scheduler.LRScheduler.__init__
# torch.autograd.function.FunctionCtx.mark_non_differentiable
# torch.nn.modules.module.Module.train
# torch._VariableFunctionsClass._foreach_addcmul_
# torch.nn.modules.module.Module.load_state_dict
# torch._VariableFunctionsClass.randperm
# torch.nn.modules.normalization.LayerNorm.reset_parameters
# torch.nn.modules.module.Module.apply
# torch.utils.weak.WeakIdRef.__call__
# torch.is_storage
# torch._VariableFunctionsClass.rand
# torch.PyCapsule.set_vital
# torch.cuda.device.__init__
# torch.cuda._lazy_init
# torch.optim.optimizer.Optimizer.__init__
# torch.optim.optimizer._stack_if_compiling
# torch.utils._pytree.tree_flatten
# torch.nn.modules.module.Module.named_modules
# torch.optim.lr_scheduler.LambdaLR.get_lr
# torch.nn.functional.cross_entropy
# torch._VariableFunctionsClass._foreach_norm
# torch._library.abstract_impl.AbstractImplHolder.register
# torch._check
# torch.xpu.random.manual_seed_all
# torch.utils.data._utils.fetch._MapDatasetFetcher.fetch
# torch.storage.TypedStorage._pickle_storage_type
# torch.distributed.rpc.internal._InternalRPCPickler._register_reducer
# torch._utils._LazySeedTracker.get_calls
# torch.is_grad_enabled
# torch._check_with
# torch.cuda.get_device_properties
# torch.serialization._check_save_filelike
# torch._prims_common.make_contiguous_strides_for
# torch._VariableFunctionsClass.exp
# torch.cuda.is_available
# torch.random._seed_custom_device
# torch.nn.parallel.data_parallel.DataParallel.replicate
# torch.nn.modules.loss.CrossEntropyLoss.forward
# torch.nn.parallel.scatter_gather.scatter_kwargs
# torch.utils.data.dataloader._get_distributed_settings
# torch._ops.OperatorBase.py_impl
# torch.nn.modules.module.Module.named_children
# torch.optim.optimizer.Optimizer.state_dict
# torch.nn.init.zeros_
# torch.storage.TypedStorage.__init__
# torch.nn.parallel.scatter_gather._is_namedtuple
# torch.storage._StorageBase.__init__
# torch.nn.modules.container.ModuleList.__init__
# torch.serialization._open_zipfile_writer
# torch.utils.data.dataloader.DataLoader.check_worker_number_rationality
# torch._VariableFunctionsClass.randn
# torch.nn.modules.module.Module._replicate_for_data_parallel
# torch.optim.optimizer.Optimizer._optimizer_step_code
# torch.cuda.graphs.is_current_stream_capturing
# torch.autocast_decrement_nesting
# torch.nn.modules.conv.Conv2d.__init__
# torch.autocast_increment_nesting
# torch.autograd.backward
# torch.nn.parallel.data_parallel.DataParallel.__init__
# torch.nn.parallel.comm.reduce_add
# torch.set_autocast_enabled
# torch.storage._StorageBase.untyped
# torch.nn.parallel.scatter_gather.scatter
# torch.cuda.random.get_rng_state
# torch._utils._element_size
# torch._decomp.get_decompositions
# torch._VariableFunctionsClass._foreach_sqrt
# torch.cuda.amp.autocast_mode.autocast.__init__
# torch.nn.parallel.comm.gather
# torch.nn.functional.dropout
# torch.utils._pytree.TreeSpec.__init__
# torch.nn.modules.module.Module.__init__
# torch.nn.init._calculate_fan_in_and_fan_out
# torch._utils.is_compiling
# torch.utils._pytree._is_namedtuple_instance
# torch.nn.modules.loss.CrossEntropyLoss.__init__
# torch._ops.OpOverload.name
# torch.optim.adamw._multi_tensor_adamw
# torch.cuda._lazy_call
# torch.distributed.is_available
# torch.nn.modules.module.Module.modules
# torch.amp.autocast_mode.autocast.__init__
# torch.utils.weak.WeakIdKeyDictionary.get
# torch._tensor.Tensor._typed_storage
# torch._prims_common.device_or_default
# torch._logging._internal.getArtifactLogger
# torch.nn.modules.module.Module.named_buffers
# torch.nn.modules.dropout._DropoutNd.__init__
# torch.is_tensor
# torch.nn.parallel.replicate._broadcast_coalesced_reshape
# torch.optim.optimizer.Optimizer._cuda_graph_capture_health_check
# torch.nn.modules.conv._ConvNd.reset_parameters
# torch.utils.data._utils.pin_memory.pin_memory
# torch.autograd.function.BackwardCFunction.apply
# torch._decomp._convert_out_params
# torch.nn.init._no_grad_trunc_normal_
# ```

# %% [markdown]
# ##### Time used
# \> 3 hours
# not feasible

# %% [markdown]
# ### Design and discussion filtering algorithm

# %% [markdown]
# #### 1. Remove magical functions
# Magic functions, typically starting and ending with double underscores (e.g., __init__, __call__), typically handle low-level Python mechanics or object manipulations rather than core application logic.  By filtering these functions out, we simplify data sets, making it easier to understand high-level processes on model training, optimization steps, and data transformations. Magic functions are always repeated at a very high frequency. Removing them prevents the distraction caused by trivial calls and unnecessary processing.
#
# ```python
# events = events.filter(~traces["function"].str.contains(r"\.__*__"))
# ```

# %% [markdown]
# #### 2. Remove private or inner functions
# FAET Relation mainly focus on high level ordered function calls group. Private and internal functions often starting with a single underscore, handle low-level operations or helper tasks (many helper function of API), which are not directly relevant to the core logic.
#
# ```python
# events = events.filter(~traces["function"].str.contains(r"\._"))
# ```

# %%
# Infer on trace_API_image_classification.log
# !time python -m mldaikon.infer_engine -t 'mldaikon/invariant/trace_API_image_classification.log' -d

# %% [markdown]
# ##### All functions:
# ```text
# torch.get_default_dtype
# torch.nn.modules.normalization.LayerNorm.forward
# torch.nn.parallel.scatter_gather.scatter
# torch.library.Library.define
# torch.is_storage
# torch.autograd.function.BackwardCFunction.apply
# torch.nn.modules.module.Module.eval
# torch.cuda.graphs.is_current_stream_capturing
# torch.nn.modules.normalization.LayerNorm.reset_parameters
# torch.cuda.is_initialized
# torch.autocast_increment_nesting
# torch.nn.parallel.data_parallel.DataParallel.scatter
# torch.distributed.distributed_c10d.is_initialized
# torch.nn.modules.module.Module.load_state_dict
# torch.nn.modules.module.Module.train
# torch.nn.modules.module.Module.zero_grad
# torch.nn.parallel.comm.gather
# torch.library.impl_abstract
# torch.clear_autocast_cache
# torch.nn.parallel.comm.reduce_add
# torch.compiler.is_compiling
# torch.nn.parallel.replicate.replicate
# torch.set_autocast_cache_enabled
# torch.nn.parallel.scatter_gather.gather
# torch.set_autocast_gpu_dtype
# torch.nn.functional.layer_norm
# torch.random.initial_seed
# torch.cuda.random.get_rng_state
# torch.nn.parallel.data_parallel.DataParallel.replicate
# torch.nn.modules.module.Module.children
# torch.random.manual_seed
# torch.nn.parallel.data_parallel.DataParallel.gather
# torch.nn.modules.loss.CrossEntropyLoss.forward
# torch.optim.adamw.adamw
# torch.serialization.location_tag
# torch.random.get_rng_state
# torch.cuda.nccl.is_available
# torch.overrides.is_tensor_like
# torch.PyCapsule.set_vital
# torch.nn.parallel.comm.broadcast_coalesced
# torch.cuda.set_stream
# torch.nn.modules.linear.Linear.forward
# torch.cuda.get_device_properties
# torch.nn.modules.module.Module.register_buffer
# torch.nn.parallel.data_parallel.DataParallel.parallel_apply
# torch.optim.lr_scheduler.LambdaLR.get_lr
# torch.is_autocast_cache_enabled
# torch.optim.lr_scheduler.LambdaLR.state_dict
# torch.utils.data.dataloader.DataLoader.check_worker_number_rationality
# torch.is_grad_enabled
# torch.nn.modules.container.ModuleList.extend
# torch.is_tensor
# torch.xpu.is_available
# torch.nn.modules.module.Module.parameters
# torch.nn.modules.module.Module.named_parameters
# torch.autocast_decrement_nesting
# torch.nn.functional.cross_entropy
# torch.nn.parameter.is_lazy
# torch.optim.optimizer.Optimizer.add_param_group
# torch.functional.atleast_1d
# torch.nn.init.ones_
# torch.serialization.save
# torch.nn.modules.module.Module.state_dict
# torch.get_autocast_gpu_dtype
# torch.nn.modules.dropout.Dropout.forward
# torch.nn.parallel.scatter_gather.scatter_kwargs
# torch.distributed.is_available
# torch.nn.parallel.comm.scatter
# torch.autograd.backward
# torch.sym_max
# torch.set_autocast_enabled
# torch.optim.optimizer.Optimizer.state_dict
# torch.mps.manual_seed
# torch.is_autocast_enabled
# torch.nn.parallel.parallel_apply.parallel_apply
# torch.xpu.<lambda>
# torch.nn.modules.module.Module.named_children
# torch.nn.modules.linear.Linear.reset_parameters
# torch.nn.modules.module.Module.named_modules
# torch.cuda.is_available
# torch.cuda.set_device
# torch.xpu.random.manual_seed_all
# torch.nn.modules.module.Module.buffers
# torch.nn.utils.clip_grad.clip_grad_norm_
# torch.cuda.stream
# torch.backends.cuda.is_built
# torch.optim.lr_scheduler.LRScheduler.get_last_lr
# torch.nn.parallel.data_parallel.DataParallel.forward
# torch.nn.init.zeros_
# torch.utils.weak.WeakIdKeyDictionary.get
# torch.nn.parallel.comm.reduce_add_coalesced
# torch.cuda.current_device
# torch.cuda.current_stream
# torch.nn.functional.dropout
# torch.nn.modules.module.Module.apply
# torch.xpu.is_initialized
# torch.nn.modules.module.Module.add_module
# torch.nn.modules.module.Module.named_buffers
# torch.optim.lr_scheduler.LRScheduler.step
# torch.nn.modules.module.Module.to
# torch.nn.modules.conv.Conv2d.forward
# torch.library.Library.impl
# torch.cuda.nccl.reduce
# torch.autograd.function.FunctionCtx.mark_non_differentiable
# torch.nn.modules.module.Module.register_parameter
# torch.nn.modules.module.Module.modules
# torch.cuda.random.manual_seed_all
# torch.distributed.rpc.is_available
# torch.nn.init.trunc_normal_
# torch.utils.hooks.warn_if_has_hooks
# torch.optim.adamw.AdamW.step
# torch.cuda.memory.empty_cache
# ```

# %% [markdown]
# ##### Time used
# 156 min
# too long

# %% [markdown]
# ##### Inferred invariants
# 3412 merged invariants in total

# %% [markdown]
# #### 3. Remove consecutive general calls
# In traces, certain API calls may occur consecutively for lots of times and these API calls are always too genernal to offer useful information. Here are two examples:
# ##### example 1: "torch.nn.modules.module.Module.named_modules"
# ```text
# {"func_call_id": "132b852e6a1b44448bc2b89b1dd606bf", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208164880, "proxy_obj_names": [["", ""]], "time": 1721240650.97207}
# {"func_call_id": "132b852e6a1b44448bc2b89b1dd606bf", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208164880, "proxy_obj_names": [["", ""]], "time": 1721240650.972082}
# {"func_call_id": "b9e3ed5c55a84616bf1204a2e0abebac", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166864, "proxy_obj_names": [["", ""]], "time": 1721240650.972106}
# {"func_call_id": "b9e3ed5c55a84616bf1204a2e0abebac", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166864, "proxy_obj_names": [["", ""]], "time": 1721240650.972117}
# {"func_call_id": "21d598b25dfc4a7e9915890e7b33ea67", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166928, "proxy_obj_names": [["", ""]], "time": 1721240650.972141}
# {"func_call_id": "21d598b25dfc4a7e9915890e7b33ea67", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166928, "proxy_obj_names": [["", ""]], "time": 1721240650.972154}
# {"func_call_id": "b96a5f3190304a6b95270144969e8902", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166992, "proxy_obj_names": [["", ""]], "time": 1721240650.972181}
# {"func_call_id": "b96a5f3190304a6b95270144969e8902", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166992, "proxy_obj_names": [["", ""]], "time": 1721240650.972193}
# {"func_call_id": "8a7e13d06f6c40a3b34204a878bac663", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166800, "proxy_obj_names": [["", ""]], "time": 1721240650.972219}
# {"func_call_id": "8a7e13d06f6c40a3b34204a878bac663", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166800, "proxy_obj_names": [["", ""]], "time": 1721240650.972232}
# {"func_call_id": "aef39e9f22624305bc172a5d3b1c6c70", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208167184, "proxy_obj_names": [["", ""]], "time": 1721240650.972258}
# {"func_call_id": "aef39e9f22624305bc172a5d3b1c6c70", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208167184, "proxy_obj_names": [["", ""]], "time": 1721240650.972271}
# {"func_call_id": "d19d6f8d3f0a4f30b812150ebb5b6161", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166032, "proxy_obj_names": [["", ""]], "time": 1721240650.972298}
# {"func_call_id": "d19d6f8d3f0a4f30b812150ebb5b6161", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166032, "proxy_obj_names": [["", ""]], "time": 1721240650.97231}
# {"func_call_id": "a8a3f1c0f30d452893b4567538431d8f", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166544, "proxy_obj_names": [["", ""]], "time": 1721240650.972335}
# {"func_call_id": "a8a3f1c0f30d452893b4567538431d8f", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166544, "proxy_obj_names": [["", ""]], "time": 1721240650.972346}
# {"func_call_id": "e6e06eeae99b4adfaee62a150f35cadd", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.nn.modules.module.Module.named_modules", "is_bound_method": true, "obj_id": 140530208166160, "proxy_obj_names": [["", ""]], "time": 1721240650.972374}
# ```
#
# In this example, "torch.nn.modules.module.Module.named_modules" occurs consecutively which is probably due to update on different model parameters. However, since the API call is too general (without noting which parameter is updated), it cannot offer furthur meaningful information for our invairant.
#
# ##### example 2: "torch.is_storage"
# ```text
# {"func_call_id": "ed91bc75439b41e3afe773f8e8113643", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.494931}
# {"func_call_id": "ed91bc75439b41e3afe773f8e8113643", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.494943}
# {"func_call_id": "9112ae703198401da765d1bf182f17f6", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.494964}
# {"func_call_id": "9112ae703198401da765d1bf182f17f6", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.494976}
# {"func_call_id": "5497484d4e704b229b9156bf35043048", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.494997}
# {"func_call_id": "5497484d4e704b229b9156bf35043048", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.495008}
# {"func_call_id": "cfa85a595f9e456c8e3f782594f98b6e", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.495029}
# {"func_call_id": "cfa85a595f9e456c8e3f782594f98b6e", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.49504}
# {"func_call_id": "62157d7df68744fdb76730180ae3bb7c", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.49506}
# {"func_call_id": "62157d7df68744fdb76730180ae3bb7c", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (post)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.495071}
# {"func_call_id": "13193e2396cb4ca4bf368950a60532ae", "thread_id": 140538694268736, "process_id": 103459, "meta_vars": {}, "type": "function_call (pre)", "function": "torch.is_storage", "is_bound_method": false, "obj_id": null, "proxy_obj_names": [["", ""]], "time": 1721240688.495092}
# ```
#
# In this example, "torch.is_storage" occurs consecutively due to storge of different part of the model. This kind of repeated behavior is always meaningless to our invariant inference and removing them can speed up the process a lot without losing important information.
#
# Use the following filter:
# ```python
#     threshold = 6
#     events = events.with_column(
#         (events["function"] != events["function"].shift()).cumsum().alias("group_id")
#     )
#
#     group_counts = events.groupby("group_id").agg([
#         pl.col("function").first().alias("function"),
#         pl.count("function").alias("count")
#     ])
#
#     functions_to_remove = group_counts.filter(pl.col("count") > threshold)["function"]
#
#     events = events.filter(~events["function"].is_in(functions_to_remove))
#     function_pool = set(events["function"].unique().to_list())
# ```
#
# Here we set threshold to be 6 (need to be futhur explored if appropriate). This means we allow at most 6 consecutive calls of a single function (including both "pre" and "post").

# %%
# Infer on trace_API_image_classification.log
# !time python -m mldaikon.infer_engine -t 'mldaikon/invariant/trace_API_image_classification.log' -d
# Out:
# /Users/xuboyu/Downloads/ml-daikon/mldaikon
# Start preprocessing....
# 23it [00:00, 77.81it/s]
# End preprocessing
# Start same level checking...
# Groups Processed: 0it [00:00, ?it/s]
# Combinations Checked: 4371it [00:00, 821163.79it/s]
#
# Combinations Checked: 4371it [00:00, 853704.44it/s]
#
# Combinations Checked: 0it [00:00, ?it/s]
# Combinations Checked: 336it [00:00, 1760.24it/s]
# Combinations Checked: 513it [00:00, 1235.72it/s]
# Combinations Checked: 4371it [00:00, 4540.86it/s]
# Groups Processed: 3it [00:00,  3.06it/s]
# Combinations Checked: 0it [00:00, ?it/s]
# Combinations Checked: 336it [00:00, 1448.50it/s]
# Combinations Checked: 481it [00:00, 993.62it/s]
# Combinations Checked: 4371it [00:01, 3800.74it/s]
# Groups Processed: 4it [00:02,  1.69it/s]
# Combinations Checked: 4371it [00:00, 882851.91it/s]
#
# Combinations Checked: 4371it [00:00, 882129.76it/s]
#
# Combinations Checked: 4371it [00:00, 55482.16it/s]
#
# Combinations Checked: 4371it [00:00, 56201.96it/s]
# ...

# %% [markdown]
# ##### All functions
# ```text
# torch.xpu.<lambda>
# torch.nn.parallel.comm.scatter
# torch.nn.parallel.data_parallel.DataParallel.parallel_apply
# torch.cuda.current_stream
# torch.optim.lr_scheduler.LRScheduler.step
# torch.nn.utils.clip_grad.clip_grad_norm_
# torch.library.impl_abstract
# torch.optim.lr_scheduler.LambdaLR.get_lr
# torch.cuda.memory.empty_cache
# torch.nn.parallel.comm.gather
# torch.random.get_rng_state
# torch.distributed.rpc.is_available
# torch.autograd.function.BackwardCFunction.apply
# torch.cuda.graphs.is_current_stream_capturing
# torch.nn.modules.module.Module.register_buffer
# torch.nn.modules.loss.CrossEntropyLoss.forward
# torch.nn.parallel.data_parallel.DataParallel.forward
# torch.nn.parallel.scatter_gather.gather
# torch.distributed.distributed_c10d.is_initialized
# torch.nn.parallel.data_parallel.DataParallel.replicate
# torch.set_autocast_gpu_dtype
# torch.nn.modules.dropout.Dropout.forward
# torch.nn.parallel.comm.broadcast_coalesced
# torch.nn.modules.normalization.LayerNorm.reset_parameters
# torch.cuda.set_device
# torch.cuda.nccl.is_available
# torch.xpu.random.manual_seed_all
# torch.nn.parameter.is_lazy
# torch.nn.modules.container.ModuleList.extend
# torch.library.Library.define
# torch.cuda.nccl.reduce
# torch.overrides.is_tensor_like
# torch.nn.modules.module.Module.train
# torch.utils.hooks.warn_if_has_hooks
# torch.nn.modules.module.Module.named_parameters
# torch.optim.optimizer.Optimizer.state_dict
# torch.nn.init.ones_
# torch.nn.parallel.comm.reduce_add
# torch.serialization.location_tag
# torch.nn.modules.module.Module.load_state_dict
# torch.optim.adamw.adamw
# torch.get_autocast_gpu_dtype
# torch.optim.lr_scheduler.LRScheduler.get_last_lr
# torch.optim.optimizer.Optimizer.add_param_group
# torch.nn.parallel.parallel_apply.parallel_apply
# torch.random.manual_seed
# torch.utils.data.dataloader.DataLoader.check_worker_number_rationality
# torch.nn.functional.layer_norm
# torch.nn.parallel.data_parallel.DataParallel.gather
# torch.nn.parallel.scatter_gather.scatter
# torch.autograd.function.FunctionCtx.mark_non_differentiable
# torch.nn.parallel.data_parallel.DataParallel.scatter
# torch.backends.cuda.is_built
# torch.nn.functional.cross_entropy
# torch.nn.modules.module.Module.zero_grad
# torch.nn.modules.module.Module.named_buffers
# torch.cuda.current_device
# torch.optim.lr_scheduler.LambdaLR.state_dict
# torch.set_autocast_enabled
# torch.is_autocast_enabled
# torch.clear_autocast_cache
# torch.nn.modules.module.Module.eval
# torch.autograd.backward
# torch.nn.modules.linear.Linear.reset_parameters
# torch.xpu.is_available
# torch.nn.init.zeros_
# torch.cuda.get_device_properties
# torch.nn.parallel.comm.reduce_add_coalesced
# torch.nn.modules.normalization.LayerNorm.forward
# torch.serialization.save
# torch.nn.parallel.scatter_gather.scatter_kwargs
# torch.autocast_increment_nesting
# torch.nn.init.trunc_normal_
# torch.nn.modules.module.Module.apply
# torch.mps.manual_seed
# torch.random.initial_seed
# torch.nn.modules.module.Module.parameters
# torch.set_autocast_cache_enabled
# torch.autocast_decrement_nesting
# torch.PyCapsule.set_vital
# torch.cuda.random.manual_seed_all
# torch.utils.weak.WeakIdKeyDictionary.get
# torch.nn.parallel.replicate.replicate
# torch.nn.modules.module.Module.children
# torch.cuda.set_stream
# torch.nn.functional.dropout
# torch.is_tensor
# torch.cuda.random.get_rng_state
# torch.optim.adamw.AdamW.step
# torch.nn.modules.module.Module.modules
# torch.xpu.is_initialized
# torch.nn.modules.module.Module.buffers
# torch.nn.modules.module.Module.to
# torch.sym_max
# ```

# %% [markdown]
# ##### Time used
# 6 min 6 seconds
# 25.6 times faster than the infer_engine without filtering algorithm
# Now feasible

# %% [markdown]
# ##### Inferred invariants
# 3366 merged invariants in total
# 2467 unconditional invariants
#
# 46 infered invarinat less compared to algorithm without removing consecutive general calls. After examination, most of the invariants lost are noises (for example with "precondition": {"func_lead": [{"clauses": [{"type": "constant", "prop_name": "group_id", "prop_dtype": "int", "values": [6889]}, {"type": "constant", "prop_name": "obj_id", "prop_dtype": "int", "values": [140530626810192]}]}]}). A few invariants lost are unconditional invariants between the consecutive functions and those functions occured only once in the inilization part, which only staisfy on this single pipeline traces and has no generality. So the invariant we lost due to remove consecutive general calls almost provide no meaningful information in the whole view of invariant inference for mutiple pipelines. The mothod of removing consecutive general calls to speed up the infer engine is legitimate.

# %% [markdown]
# ### Current justified filtering algorithm
# ```python
#     events = trace.events
#     events = events.filter(~events["function"].str.contains(r"\.__*__"))
#     events = events.filter(~events["function"].str.contains(r"\._"))
#     threshold = 6
#     events = events.with_columns(
#         (events["function"] != events["function"].shift()).cum_sum().alias("group_id")
#     )
#     group_counts = events.group_by("group_id").agg([
#         pl.col("function").first().alias("function"),
#         pl.count("function").alias("count")
#     ])
#     functions_to_remove = group_counts.filter(pl.col("count") > threshold)["function"]
#     events = events.filter(~events["function"].is_in(functions_to_remove))
#     function_pool = set(events["function"].unique().to_list())
# ```

# %% [markdown]
# ### 4. Furthur function fitering algorithm
# We may explore fitering algorithm together with static analysis.
